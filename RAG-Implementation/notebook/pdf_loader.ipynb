# %% [markdown]
# ### RAG pipelines - Data Ingestion to Vector DB Pipeline

# %%
import os
from pathlib import Path

from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
### Read all the pdfs isnide the directory

def process_all_pdfs(pdf_directory):
    """Process all PDF files in a diretory"""
    all_documents=[]
    pdf_dir =Path(pdf_directory)



    # Find all the pdf files recursively
    pdf_files=list(pdf_dir.glob("**/*.pdf"))
    print(f"Found{len(pdf_files)} PDF files to process")
    
    for pdf_file in pdf_files:
        print(f"\nProcessing : {pdf_file.name}")
        try:
            loader=PyPDFLoader(str(pdf_file))
            documents=loader.load()

            # Add sourc information to metadata
            for doc in documents:
                doc.metadata['source_file']=pdf_file.name
                doc.metadata['file_type']='pdf'


            all_documents.extend(documents)
            print(f" Loaded {len(documents)} pages")

        except Exception as e:
            print(f" Error:{e}")


    print(f"\nTOTAL Documents loaded: {len(all_documents)}")
    return all_documents


# Process all PDFs in the data directory
all_pdf_documents=process_all_pdfs("../data")
# Out:
# Found3 PDF files to process
#
# Processing : Chapter 11- Marketing.pdf
#  Loaded 32 pages
#
# Processing : RISK MANAGEMENT.pdf
#  Loaded 5 pages
#
# Processing : sample.pdf
#  Loaded 1 pages
#
# TOTAL Documents loaded: 38

# %%
all_pdf_documents
# Out:
# [Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 0, 'page_label': '1', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Unique \nMarketing issue\nChapter 11'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 1, 'page_label': '2', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Selecting a \nMarket and \nEstablishing a \nPosition in the \nMarket\n• In order to succeed, a new firm must address this\nimportant issue: Who are our customers are how\nwill we appeal to them?\n• A well-managed start-up approaches this query by\nfollowing a three-step process:\n• Segmenting the market. S\n• Selecting a target market. T\n• Establishing a unique position in the target\nmarket P\n11-2'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 2, 'page_label': '3', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='11-3\nThe Process of Selecting a Target Market and \nPositioning Strategy'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 3, 'page_label': '4', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Positioning Strategy?'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 4, 'page_label': '5', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Market Segmentation\nBases for Segmenting Consumer \nGeographic\nDemographic\nAge, gender, \nfamily size and \nlife cycle,  or income \nPsychographic\nBehavioral\nNations, states, \nregions or cities'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 5, 'page_label': '6', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Selecting A Target Market\n•Once a firm has segmented \n  the market, a target market\n  must be chosen.\n• The market must be \nsufficiently\n  attractive and the firm must \nhave\n  the capability to serve it.\n3-6'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 6, 'page_label': '7', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Establishing a \nUnique \nPosition\n•Positioning\n3-7\n• After selecting a target market, the firm’s next step is to \nestablish  “position” within the market that differentiates it \nfrom its rivals.\n• A “position” is the part of a market that the firm is \nclaiming as its own.\n• A firm establishing a unique position in its customers’ \nminds by drawing attention to two or \n  three of the product’s attributes.'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 7, 'page_label': '8', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Establishing a Unique Position'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 8, 'page_label': '9', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='11-9\nSelling Benefits Rather Than Features\n• Selling Benefits Rather Than Features\n• Many entrepreneur make the mistake of positioning their company’s products \nor services on features rather than benefits.\n• A positioning or marketing strategy that focuses on the features of a product, \nsuch as its technical merits, is usually much less effective than a campaign \nfocusing on what the merits of the product can do.'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 9, 'page_label': '10', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Positioning \n• Just do it (Nike)\n• Eat fresh (Subway)\n• Think Different" – Apple\n• "Open Happiness" - Coca-Cola\nSelling Benefits Rather Than Features'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 10, 'page_label': '11', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Establishing a Brand\n• A brand is the set of attributes—positive \nor negative—that people associated with a \ncompany.\n• These attributes can be positive, such as \ntrustworthy, dependable, or easy to deal \nwith.\n• The customer loyalty a company creates \nthrough its brand is one of its most valuable \nassets.'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 11, 'page_label': '12', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='A product is something that is made in a factory;  a \nbrand is something that is bought by a customer.  A \nproduct can be copied by a competitor, a brand is \nunique.  A product can be quickly outdated; a \nsuccessful brand is timeless.\nA brand is something that resides in the minds of \nconsumer.\n            More emotional \nWHAT    IS      BRAND'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 12, 'page_label': '13', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='11-13\nThe Four Ps of Marketing for New Ventures\nMarketing Mix\nProduct Price\nPromotion Place (or \ndistribution)'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 13, 'page_label': '14', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Product\n• Is the good or service a firm offers to its \ntarget market.  \n• All firms face the challenge that they are \nunknown and that it takes a leap of faith for \nthe first customers to buy their products.\n• Some startups meet this challenge by \nusing reference accounts.'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 14, 'page_label': '15', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='11-15\nCore Product vs. Actual Product\nCore Product Actual Product\nPurpose of a product. The product plus all the \nattributes that come \nwith it such as quality \nlevel, features, design, \npackaging, and  \nwarranty.'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 15, 'page_label': '16', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Core Product \nvs. Actual \nProduct'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 16, 'page_label': '17', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Price\n• Price is the amount of money consumers pay to buy a \nproduct. \n• The price a company charges for its products sends an \nimportant message to its target market.\n• Most entrepreneurs use one of two methods to set the price \nfor their products, as shown on the next slide.'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 17, 'page_label': '18', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='11-18\nPricing\nCost-Based Pricing Value-Based Pricing\nThe list price is \ndetermined by adding a \nmarkup percentage to a \nproduct’s cost.\nThe list price is \ndetermined by \nestimating what \nconsumers are will to \npay for a product.'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 18, 'page_label': '19', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content=''),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 19, 'page_label': '20', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content=''),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 20, 'page_label': '21', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Promotion\n11-21\nPromotion\n• Refers to the activities the firm takes to \ncommunicate the merits of its product to \nits target market. \n• There are several common activities that \nentrepreneurs use to promote their \nproducts and services.\nAdvertising\n• Advertising is making people aware of a \nproduct or service in hopes of \npersuading them to buy it.'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 21, 'page_label': '22', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content=''),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 22, 'page_label': '23', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content=''),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 23, 'page_label': '24', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content=''),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 24, 'page_label': '25', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Public Relations\nLower cost than advertising\n Stronger impact on public \nawareness than advertising\nThe Role and Impact of Public Relations'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 25, 'page_label': '26', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Difference'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 26, 'page_label': '27', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='11-28\nPublic Relations Techniques\nPress release\nArticles in industry\npress \nsocial, and community\ninvolvement\nMedia coverage\nBlogging\nNews conference'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 27, 'page_label': '28', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='11-29\nOther Promotions Techniques\nViral Marketing Guerrilla Marketing\nFacilitates and \nencourages people to \npass along a marketing \nmessage about a \nparticular product or \nservice.\nA approach to \nmarketing that relies on \ningenuity, cleverness, \nand surprise rather than \ntraditional techniques.'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 28, 'page_label': '29', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='Place (or Distribution)\n• Encompasses all the activities that move a \nfirm’s product from its place of origin to the \nconsumer.  \n• The first choice a firm must make regarding \ndistribution is whether to sell its products \ndirectly to consumers or through \nintermediaries (such as wholesalers and \nretailers).'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 29, 'page_label': '30', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='11-31\nSelling Direct Vs. Selling Through an \nIntermediary\n1 of 2\nApproach to \nDistribution\nDescription\nSelling \nDirect\nSelling Through \nIntermediaries\nMany firms sell direct to customer, maintaining control \nof the distribution and sales process.  \nOther firms sell through intermediaries and pass off \ntheir products to wholesalers who place them in retail \noutlets to be sold.'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 30, 'page_label': '31', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='11-32\nSelling Direct Versus Selling Through a \nIntermediary\n2 of 2'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® 2024', 'creator': 'Microsoft® PowerPoint® 2024', 'creationdate': '2026-05-16T13:10:30+05:00', 'title': 'Unique  Marketing issue', 'author': 'Jehanzaib Akram', 'moddate': '2026-05-16T13:10:30+05:00', 'source': '..\\data\\pdf\\Chapter 11- Marketing.pdf', 'total_pages': 32, 'page': 31, 'page_label': '32', 'source_file': 'Chapter 11- Marketing.pdf', 'file_type': 'pdf'}, page_content='https://www.youtube.com/watch?v=5yRB3zzqdV4&\nfeature=youtu.be\nLecture Video'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-04-26T15:33:46+05:00', 'author': 'tahreem fatima', 'moddate': '2026-04-26T15:33:46+05:00', 'source': '..\\data\\pdf\\RISK MANAGEMENT.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'source_file': 'RISK MANAGEMENT.pdf', 'file_type': 'pdf'}, page_content='RISK \nMANAGEMENT \n1. Risk Management Approach \nThe project will follow a PMBOK 8 uncertainty-based risk management approach, \nwhere both threats and opportunities are identified and managed to maximize project \nvalue. \n• Risks will be identified using TECOP (Technical, External, Commercial, \nOrganisational, Project Management) categories  \n• Risk analysis will include qualitative (Probability × Impact) and basic \nquantitative (EMV) techniques  \n• Each risk will have a defined owner and response strategy  \n• Risks will be continuously monitored throughout the project lifecycle  \n• A risk register will be maintained and updated regularly  \n \n2.Risk Identification: \nR1 – Technical \nBecause the AI model may not fully understand uploaded content, there is a risk that \nirrelevant or incorrect questions are generated, which could result in poor quiz \nquality and reduced user trust. \nR2 – Technical \nBecause the system may face high concurrent usage, there is a risk that performance \nissues or system crashes occur, which could result in delays and failed quiz \nattempts. \nR3 – External \nBecause the project depends on third-party AI APIs, there is a risk that API service \nbecomes unavailable or changes, which could result in AI module failure.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-04-26T15:33:46+05:00', 'author': 'tahreem fatima', 'moddate': '2026-04-26T15:33:46+05:00', 'source': '..\\data\\pdf\\RISK MANAGEMENT.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'source_file': 'RISK MANAGEMENT.pdf', 'file_type': 'pdf'}, page_content='R4 – Organisational \nBecause team members have limited experience with AI integration, there is a risk that \ndevelopment delays occur, which could result in missing deadlines. \nR5 – Project Management \nBecause requirements may evolve during development, there is a risk that scope creep \noccurs, which could result in increased workload and timeline delays. \nOPP1 – Opportunity \nBecause AI integration is innovative, there is an opportunity that the system gains high \nacademic recognition, which could result in better grades and future project \nscalability. \n3. Risk Analysis \n3.1 Qualitative Analysis (P × I) \nID Risk P I Score Priority \nR1 AI inaccurate output 0.6 0.7 42 Critical \nR2 System performance issues 0.5 0.8 40 Critical \nR3 API failure 0.4 0.7 28 High \nR4 Team skill gap 0.5 0.6 30 High \nR5 Scope creep 0.6 0.5 30 High \nOPP1 Academic recognition 0.4 0.8 32 Opportunity \n \n3.2 Quantitative Analysis (EMV) \nRisk P Impact (PKR) EMV \nR1 0.6 -30,000 -18,000 \nR2 0.5 -50,000 -25,000 \nR3 0.4 -40,000 -16,000 \nOPP1 0.4 +60,000 +24,000'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-04-26T15:33:46+05:00', 'author': 'tahreem fatima', 'moddate': '2026-04-26T15:33:46+05:00', 'source': '..\\data\\pdf\\RISK MANAGEMENT.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3', 'source_file': 'RISK MANAGEMENT.pdf', 'file_type': 'pdf'}, page_content='Total EMV ≈ -35,000 PKR \n Recommended contingency reserve ≈ 35K PKR \n4. Risk Response Planning: \n4.1 Threat Strategies (4Ts) \nR1 – AI Incorrect Questions → MITIGATE \n• Add manual editing feature  \n• Test AI output before publishing  \n• Owner: AI Developer  \n• Trigger: >20% incorrect questions  \nR2 – System Performance Issues → MITIGATE \n• Optimize backend  \n• Use scalable services (Firebase)  \n• Owner: Backend Developer  \n• Trigger: Slow response > 3 sec \nR3 – API Failure → TRANSFER + MITIGATE \n• Use backup API / fallback logic  \n• Cache generated questions  \n• Owner: Developer  \n• Trigger: API downtime  \nR4 – Skill Gap → MITIGATE \n• Use tutorials, documentation  \n• Divide tasks based on expertise  \n• Owner: Project Manager \nR5 – Scope Creep → AVOID \n• Freeze requirements after approval  \n• Use MoSCoW prioritization  \n• Owner: Project Manager'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-04-26T15:33:46+05:00', 'author': 'tahreem fatima', 'moddate': '2026-04-26T15:33:46+05:00', 'source': '..\\data\\pdf\\RISK MANAGEMENT.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'source_file': 'RISK MANAGEMENT.pdf', 'file_type': 'pdf'}, page_content='4.2 Opportunity Strategy \nOPP1 – Academic Recognition → EXPLOIT \n• Focus on AI feature quality  \n• Improve UI/UX for presentation  \n• Owner: Project Manager \n5. Contingency & Fallback Plans \n \nRisk: AI generates poor questions \n• Contingency Plan:  \no Allow teachers to edit questions  \no Use predefined question bank  \n• Fallback Plan:  \no Disable AI feature and use manual quiz creation only  \n6. Risk Monitoring & Control \n• Weekly risk review meetings  \n• Update risk register regularly  \n• Track risk status (Open / Closed / Mitigated)  \n• Identify new risks during development  \n• Reassess probability and impact \n7.Risk Register: \nID Risk Cat. P I Score Owner Strategy Status \nR1 AI inaccurate output Tech 0.6 0.7 42 AI Dev Mitigate Open \nR2 Performance issues Tech 0.5 0.8 40 Backend Dev Mitigate Open \nR3 API failure External 0.4 0.7 28 Dev Transfer Open \nR4 Skill gap Org 0.5 0.6 30 PM Mitigate Open'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-04-26T15:33:46+05:00', 'author': 'tahreem fatima', 'moddate': '2026-04-26T15:33:46+05:00', 'source': '..\\data\\pdf\\RISK MANAGEMENT.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5', 'source_file': 'RISK MANAGEMENT.pdf', 'file_type': 'pdf'}, page_content='ID Risk Cat. P I Score Owner Strategy Status \nR5 Scope creep PM 0.6 0.5 30 PM Avoid Open \nOPP1 Academic success PM 0.4 0.8 32 Team Exploit Open'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': '..\\data\\pdf\\sample.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'source_file': 'sample.pdf', 'file_type': 'pdf'}, page_content='This is a sample PDF for RAG.')]

# %% [markdown]
# ### Chunking

# %%
### Text Splitting get into chunks

def split_documents(documents,chunk_size=1000,chunk_overlap=200):
    """Split documents into smaller chunks for better RAG performance"""
    text_splitter =RecursionError(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function =len,
        separators=["\n\n","\n"," ",""]
    )
    split_docs = text_splitter.split_documents(documents)
    print(f"Split {len(documents)} documents into {len(split_docs)} chunks")


    # Show example of a chunk
    if split_docs:
        print(f"\n Example chunk:")
        print(f"Content: {split_docs[0].page_content[:200]}...")
        print(f"Metadata:{split_docs[0].metadata}")

    return split_docs

# %%
chunks=split_documents(all_pdf_documents)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 chunks=split_documents(all_pdf_documents)
#
# Cell In[8], line 5, in split_documents(documents, chunk_size, chunk_overlap)
#       3 def split_documents(documents,chunk_size=1000,chunk_overlap=200):
#       4     """Split documents into smaller chunks for better RAG performance"""
# ----> 5     text_splitter =RecursionError(
#       6         chunk_size=chunk_size,
#       7         chunk_overlap=chunk_overlap,
#       8         length_function =len,
#
# TypeError: RecursionError() takes no keyword arguments
