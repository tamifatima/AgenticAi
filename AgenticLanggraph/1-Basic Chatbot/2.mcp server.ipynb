# %% [markdown]
# ### Integrating mcp servers
#
#
#
# mcp server is connected to some third party tools.,so llm can make a tool call to mcp servers through mcp protocols
#
# We will use langchain adapter library
#
# there are diff transpot protocols we use -->stdio,http
#
#
# tools--> stdio,http
